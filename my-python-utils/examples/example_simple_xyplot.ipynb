# %%
#
# Set up the levels to interpolate to. In this case meters AGL
#

interp_levels = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000]
MAE = [0.4967, 0.4759, 0.4505, 0.4449, 0.3816, 0.3842, 0.3266, 0.3135, 0.2594, 0.2713, 0.2533, 0.2178, 0.2636]
loss = [0.1296, 0.1205, 0.1162, 0.1088, 0.0939, 0.0848, 0.0646,  0.0602,  0.0448, 0.0484, 0.0448, 0.0372, 0.0485]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(interp_levels, MAE)
plt.xlabel('height (m)')
plt.ylabel('Mean Absolute Error')
plt.savefig("/glade/work/hardt/MAE_plot.png", dpi=200)

# %%
plt.plot(interp_levels, loss)
plt.xlabel('height (m)')
plt.ylabel('loss')
plt.savefig("/glade/work/hardt/loss_plot.png", dpi=200)
